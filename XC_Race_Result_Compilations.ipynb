# %% [markdown]
# <a href="https://colab.research.google.com/github/syphax/running-analysis/blob/main/XC_Race_Result_Compilations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests
import pandas as pd
import numpy as np

# %%
def get_milesplit_results(url):
  '''
  url: Complete URL for results, complete with parameters

  Yes, I know I should break the url into the endpoint and parameters,
  but for v0.1 I'm just using monolithic URLs
  '''

  response = requests.get(url)

  # Check if the request was successful
  if response.status_code == 200:
      # Parse the response JSON if the content type is correct
      if 'application/json' in response.headers.get('Content-Type'):

          # Get the full response
          full_response = response.json()

          # Get the data grid and make a DataFrame
          df_result_full = pd.DataFrame(full_response['data'])

          # Drop some fields
          df_result = df_result_full.drop(['teamProfileUrl', 'profileUrl', 'teamLogo'], axis=1)


          print('Success getting data from {}'.format(url))
      else:
          print('Response content is not in JSON format.')
          df_result = None
  else:
      print(f'Error: {response.status_code}')
      print(response.text)
      df_result = None

  return df_result

# %%
# Thanks ChatGPT:

def convert_to_timedelta(time_str):
    # Split the string into minutes, seconds, and hundredths
    minutes, seconds = time_str.split(':')
    seconds, hundredths = seconds.split('.')

    # Convert each part to timedelta
    minutes_delta = pd.Timedelta(minutes=int(minutes))
    seconds_delta = pd.Timedelta(seconds=int(seconds))
    hundredths_delta = pd.Timedelta(milliseconds=int(hundredths) * 10)

    # Sum up the deltas to get the total timedelta
    total_delta = minutes_delta + seconds_delta + hundredths_delta
    return total_delta

# My go-to column name flattener:

def flatten_columns(df, joiner='_'):
    df.columns = df.columns.map(joiner.join).str.strip(joiner)
    return df

# %%
# List of dicts of races:

race_dict = {'Cape Ann':'https://ma.milesplit.com/api/v1/meets/578420/performances?resultsId=986788&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Bay State':'https://ma.milesplit.com/api/v1/meets/577861/performances?resultsId=986854&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Middlesex':'https://ma.milesplit.com/api/v1/meets/580397/performances?resultsId=987179&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Cape and Islands':'https://ma.milesplit.com/api/v1/meets/579796/performances?resultsId=986665&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Catholic Mem Invite':'https://ma.milesplit.com/api/v1/meets/578923/performances?resultsId=979826&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Patriot':'https://ma.milesplit.com/api/v1/meets/572358/performances?resultsId=986745&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Merrimack':'https://ma.milesplit.com/api/v1/meets/580308/performances?resultsId=986653&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Dual County Thorpe 2':' https://ma.milesplit.com/api/v1/meets/572592/performances?resultsId=985976&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Dual County Thorpe 1':'https://ma.milesplit.com/api/v1/meets/572592/performances?resultsId=985975&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Dual County Foley':'https://ma.milesplit.com/api/v1/meets/572592/performances?resultsId=985973&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',
             'Hockomock':'https://ma.milesplit.com/api/v1/meets/572508/performances?resultsId=986801&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true',

             }

locations_dict = {'Cape Ann':'Wrentham',
                  'Bay State':'Wrentham',
                  'Middlesex':'Woburn Country Club',
                  'Cape and Islands':'Dennis-Yarmouth',
                  'Catholic Mem Invite':'Franklin Park',
                  'Patriot':'Hingham',
                  'Merrimack':'Shedd Park',
                  'Dual County Thorpe 2':'Franklin Park',
                  'Dual County Thorpe 1':'Franklin Park',
                  'Dual County Foley':'Franklin Park',
                  'Hockomock':'Wrentham'
                  }

# %%
list_results = []

for r in race_dict.keys():
  print(r)
  result = get_milesplit_results(race_dict[r])
  result['Race Key'] = r
  result['Location'] = locations_dict[r]

  list_results.append(result)

df_results = pd.concat(list_results, axis=0)
# Out:
# Cape Ann
# Success getting data from https://ma.milesplit.com/api/v1/meets/578420/performances?resultsId=986788&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Bay State
# Success getting data from https://ma.milesplit.com/api/v1/meets/577861/performances?resultsId=986854&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Middlesex
# Success getting data from https://ma.milesplit.com/api/v1/meets/580397/performances?resultsId=987179&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Cape and Islands
# Success getting data from https://ma.milesplit.com/api/v1/meets/579796/performances?resultsId=986665&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Catholic Mem Invite
# Success getting data from https://ma.milesplit.com/api/v1/meets/578923/performances?resultsId=979826&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Patriot
# Success getting data from https://ma.milesplit.com/api/v1/meets/572358/performances?resultsId=986745&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Merrimack
# Success getting data from https://ma.milesplit.com/api/v1/meets/580308/performances?resultsId=986653&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Dual County Thorpe 2
# Success getting data from  https://ma.milesplit.com/api/v1/meets/572592/performances?resultsId=985976&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Dual County Thorpe 1
# Success getting data from https://ma.milesplit.com/api/v1/meets/572592/performances?resultsId=985975&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Dual County Foley
# Success getting data from https://ma.milesplit.com/api/v1/meets/572592/performances?resultsId=985973&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true
# Hockomock
# Success getting data from https://ma.milesplit.com/api/v1/meets/572508/performances?resultsId=986801&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true

# %%
# Additional Info

df_results['Full Name'] = df_results['firstName'] + ' ' + df_results['lastName']

# %%
# Fixes

df_results['Race Name'] = np.where(df_results['Race Key'].isin(['Dual County Thorpe 1', 'Dual County Thorpe 2', 'Dual County Foley']), 'Dual County', df_results['Race Key'])

# %%
# Convert marks to time deltas:

df_results['Time'] = df_results['mark'].apply(convert_to_timedelta)

df_results['Time_str'] = df_results['Time'].astype(str).map(lambda x: x[7:18])
#df_results['Time'] = df_results['mark'].apply(lambda x: pd.to_timedelta(x))

# %%
df_results[['mark', 'Time', 'Time_str']].sample(5)
# Out:
#          mark                   Time     Time_str
# 698  21:34.10 0 days 00:21:34.100000  00:21:34.10
# 671  20:52.40 0 days 00:20:52.400000  00:20:52.40
# 690  21:27.20 0 days 00:21:27.200000  00:21:27.20
# 256  11:08.30 0 days 00:11:08.300000  00:11:08.30
# 215  18:38.60 0 days 00:18:38.600000  00:18:38.60

# %% [markdown]
# # Trim and Clean Data

# %%
df_results_bak = df_results.copy()

# %%
print(df_results.shape)
df_results = df_results[df_results['gender']=='M']
print(df_results.shape)
df_results = df_results[df_results['eventCode']=='5000m']
print(df_results.shape)
# Out:
# (2283, 33)
# (1599, 33)
# (1380, 33)

# %%
df_results = df_results.sort_values(['Race Name', 'mark'], ascending=True)

# %%
df_results['Team Place'] = df_results.groupby(['Race Name', 'teamName']).cumcount() + 1

# %%
df_results_top7 = df_results[df_results['Team Place'] <= 7]

# %%
df_results_team = df_results_top7.groupby(['Race Name', 'Location', 'teamName'], as_index=False).agg(
    {'athleteId':'nunique', 'Time':['min','mean','max']})

df_results_team = flatten_columns(df_results_team)

df_results_team['Runners'] = df_results_team['athleteId_nunique']
df_results_team['Time-fastest'] = df_results_team['Time_min'].astype(str).map(lambda x: x[7:18])
df_results_team['Time-mean'] = df_results_team['Time_mean'].astype(str).map(lambda x: x[7:18])
df_results_team['Time-slowest'] = df_results_team['Time_max'].astype(str).map(lambda x: x[7:18])

df_results_team_formatted = df_results_team[['teamName', 'Race Name', 'Location', 'Runners', 'Time-fastest', 'Time-mean', 'Time-slowest']]

# %%
df_results_team
# Out:
#      Race Name  Location                             teamName  \
# 0    Bay State  Wrentham                Braintree High School
# 1    Bay State  Wrentham                Brookline High School
# 2    Bay State  Wrentham               Framingham High School
# 3    Bay State  Wrentham                   Milton High School
# 4    Bay State  Wrentham                   Natick High School
# ..         ...       ...                                  ...
# 125    Patriot   Hingham           Plymouth North High School
# 126    Patriot   Hingham           Plymouth South High School
# 127    Patriot   Hingham                 Scituate High School
# 128    Patriot   Hingham     Silver Lake Regional High School
# 129    Patriot   Hingham  Whitman Hanson Regional High School
#
#      athleteId_nunique               Time_min                 Time_mean  \
# 0                    7 0 days 00:17:44.200000    0 days 00:18:49.600000
# 1                    7 0 days 00:16:00.600000 0 days 00:16:28.128571428
# 2                    7 0 days 00:17:49.300000    0 days 00:18:48.800000
# 3                    7        0 days 00:17:34 0 days 00:19:03.357142857
# 4                    7 0 days 00:16:23.600000 0 days 00:16:56.814285714
# ..                 ...                    ...                       ...
# 125                  7 0 days 00:17:07.910000    0 days 00:19:12.740000
# 126                  7 0 days 00:16:02.910000 0 days 00:17:15.424285714
# 127                  7 0 days 00:17:23.890000 0 days 00:19:10.431428571
# 128                  7 0 days 00:17:48.790000 0 days 00:18:45.535714285
# 129                  7 0 days 00:17:04.120000 0 days 00:18:54.305714285
#
#                   Time_max  Runners Time-fastest    Time-mean Time-slowest
# 0   0 days 00:19:44.300000        7  00:17:44.20  00:18:49.60  00:19:44.30
# 1          0 days 00:17:13        7  00:16:00.60  00:16:28.12     00:17:13
# 2   0 days 00:20:03.300000        7  00:17:49.30  00:18:48.80  00:20:03.30
# 3   0 days 00:20:40.100000        7     00:17:34  00:19:03.35  00:20:40.10
# 4          0 days 00:17:43        7  00:16:23.60  00:16:56.81     00:17:43
# ..                     ...      ...          ...          ...          ...
# 125 0 days 00:22:27.740000        7  00:17:07.91  00:19:12.74  00:22:27.74
# 126 0 days 00:18:58.610000        7  00:16:02.91  00:17:15.42  00:18:58.61
# 127 0 days 00:21:01.590000        7  00:17:23.89  00:19:10.43  00:21:01.59
# 128 0 days 00:19:36.160000        7  00:17:48.79  00:18:45.53  00:19:36.16
# 129 0 days 00:20:25.690000        7  00:17:04.12  00:18:54.30  00:20:25.69
#
# [130 rows x 11 columns]

# %%
df_results_top7[df_results_top7['teamName']==' High School']
# Out:
# Empty DataFrame
# Columns: [id, eventCode, gender, athleteId, meetId, teamId, round, heat, place, windReading, units, teamName, firstName, lastName, gradYear, eventName, eventDistance, ageGroupName, meetName, videoId, divisionId, divisionName, roundName, genderName, eventGenreOrder, performanceVideoId, mark, Race Key, Location, Full Name, Race Name, Time, Time_str, Team Place]
# Index: []
#
# [0 rows x 34 columns]

# %%
df_results_team_formatted.to_csv('team_results_formatted.csv')

# %%
df_results_top7.to_csv('individual_results.csv')

# %% [markdown]
# # Checks and Diagnostics

# %%
df_results.groupby('Race Name').agg({'id':'count'})
# Out:
#                       id
# Race Name
# Bay State            173
# Cape Ann              70
# Cape and Islands     108
# Catholic Mem Invite  426
# Dual County           75
# Hockomock            107
# Merrimack             81
# Middlesex            246
# Patriot               94

# %%
df_results.groupby(['Race Name', 'meetId']).agg({'id':'count', 'Full Name':'nunique'})
# Out:
#                              id  Full Name
# Race Name           meetId
# Bay State           577861  173        173
# Cape Ann            578420   70         70
# Cape and Islands    579796  108        108
# Catholic Mem Invite 578923  426        426
# Dual County         572592   75         75
# Hockomock           572508  107        107
# Merrimack           580308   81         81
# Middlesex           580397  246        246
# Patriot             572358   94         93

# %%
df_results[df_results['meetId']=='578923'].groupby(['eventCode', 'gender', 'round', 'heat', 'divisionId']).agg({'id':'count', 'Full Name':'nunique'})
# Out:
#                                          id  Full Name
# eventCode gender round heat divisionId
# 5000m     M      f     1    110         140        140
#                             72          178        178
#                             92          108        108

# %%
df_results[df_results['meetId']=='578923'].sample(10).T
# Out:
#                                                 528  \
# id                                        151731696
# eventCode                                     5000m
# gender                                            M
# athleteId                                  11339945
# meetId                                       578923
# teamId                                        19674
# round                                             f
# heat                                              1
# place                                            39
# windReading
# units                                       1116800
# teamName                      Toll Gate High School
# firstName                                  Rhontahn
# lastName                                       Vega
# gradYear                                       2024
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                       92
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       18:36.80
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                             Rhontahn Vega
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:18:36.800000
# Time_str                                00:18:36.80
# Team Place                                        3
#
#                                                 527  \
# id                                        151732072
# eventCode                                     5000m
# gender                                            M
# athleteId                                  11432223
# meetId                                       578923
# teamId                                        15203
# round                                             f
# heat                                              1
# place                                            13
# windReading
# units                                       1116600
# teamName                         Pinkerton Academy
# firstName                                   Michael
# lastName                                    Griffin
# gradYear                                       2025
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                       72
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       18:36.60
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                           Michael Griffin
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:18:36.600000
# Time_str                                00:18:36.60
# Team Place                                       12
#
#                                                     722  \
# id                                            151731653
# eventCode                                         5000m
# gender                                                M
# athleteId                                       9279109
# meetId                                           578923
# teamId                                            19429
# round                                                 f
# heat                                                  1
# place                                               136
# windReading
# units                                           1326000
# teamName            Whitman Hanson Regional High School
# firstName                                          Adam
# lastName                                         Vinton
# gradYear                                           2024
# eventName                                5000 Meter Run
# eventDistance                                      5000
# ageGroupName                                       None
# meetName                Cathlolic Memorial Invitational
# videoId                                               0
# divisionId                                          110
# divisionName                                       None
# roundName                                        Finals
# genderName                                         Boys
# eventGenreOrder                                       2
# performanceVideoId                                 None
# mark                                           22:06.00
# Race Key                            Catholic Mem Invite
# Location                                  Franklin Park
# Full Name                                   Adam Vinton
# Race Name                           Catholic Mem Invite
# Time                                    0 days 00:22:06
# Time_str                                       00:22:06
# Team Place                                            9
#
#                                                      603  \
# id                                             151732103
# eventCode                                          5000m
# gender                                                 M
# athleteId                                       12545126
# meetId                                            578923
# teamId                                             19179
# round                                                  f
# heat                                                   1
# place                                                 44
# windReading
# units                                            1186800
# teamName            Amherst-Pelham  Regional High School
# firstName                                           Niko
# lastName                                        Ringkauf
# gradYear                                            2024
# eventName                                 5000 Meter Run
# eventDistance                                       5000
# ageGroupName                                        None
# meetName                 Cathlolic Memorial Invitational
# videoId                                                0
# divisionId                                            72
# divisionName                                        None
# roundName                                         Finals
# genderName                                          Boys
# eventGenreOrder                                        2
# performanceVideoId                                  None
# mark                                            19:46.80
# Race Key                             Catholic Mem Invite
# Location                                   Franklin Park
# Full Name                                  Niko Ringkauf
# Race Name                            Catholic Mem Invite
# Time                              0 days 00:19:46.800000
# Time_str                                     00:19:46.80
# Team Place                                             7
#
#                                                 440  \
# id                                        151731531
# eventCode                                     5000m
# gender                                            M
# athleteId                                  11178982
# meetId                                       578923
# teamId                                        14375
# round                                             f
# heat                                              1
# place                                            43
# windReading
# units                                       1049600
# teamName                   Nashua South High School
# firstName                                      Ryan
# lastName                                   DuVarney
# gradYear                                       2025
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                      110
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       17:29.60
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                             Ryan DuVarney
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:17:29.600000
# Time_str                                00:17:29.60
# Team Place                                        4
#
#                                                 680  \
# id                                        151732135
# eventCode                                     5000m
# gender                                            M
# athleteId                                  13985178
# meetId                                       578923
# teamId                                        19366
# round                                             f
# heat                                              1
# place                                            76
# windReading
# units                                       1263600
# teamName                 Plymouth North High School
# firstName                                     James
# lastName                                   Twombley
# gradYear                                       2025
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                       72
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       21:03.60
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                            James Twombley
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:21:03.600000
# Time_str                                00:21:03.60
# Team Place                                        7
#
#                                                 798  \
# id                                        151732226
# eventCode                                     5000m
# gender                                            M
# athleteId                                  13956634
# meetId                                       578923
# teamId                                        19198
# round                                             f
# heat                                              1
# place                                           167
# windReading
# units                                       1493900
# teamName                        Beverly High School
# firstName                                  Harrison
# lastName                                   Finamore
# gradYear                                       2026
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                       72
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       24:53.90
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                         Harrison Finamore
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:24:53.900000
# Time_str                                00:24:53.90
# Team Place                                       22
#
#                                                 545  \
# id                                        151732079
# eventCode                                     5000m
# gender                                            M
# athleteId                                  12659434
# meetId                                       578923
# teamId                                        19297
# round                                             f
# heat                                              1
# place                                            20
# windReading
# units                                       1128600
# teamName                         Lowell High School
# firstName                                    Jayden
# lastName                                   Ferreras
# gradYear                                       2026
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                       72
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       18:48.60
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                           Jayden Ferreras
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:18:48.600000
# Time_str                                00:18:48.60
# Team Place                                        3
#
#                                                 393  \
# id                                        151731452
# eventCode                                     5000m
# gender                                            M
# athleteId                                  10248410
# meetId                                       578923
# teamId                                        14710
# round                                             f
# heat                                              1
# place                                             6
# windReading
# units                                        972200
# teamName                          Coe Brown Academy
# firstName                                     Jamie
# lastName                                       Lano
# gradYear                                       2024
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                      110
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       16:12.20
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                                Jamie Lano
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:16:12.200000
# Time_str                                00:16:12.20
# Team Place                                        1
#
#                                                 754
# id                                        151732188
# eventCode                                     5000m
# gender                                            M
# athleteId                                  13937906
# meetId                                       578923
# teamId                                        19316
# round                                             f
# heat                                              1
# place                                           129
# windReading
# units                                       1380900
# teamName                        Methuen High School
# firstName                                    Javien
# lastName                                       Leon
# gradYear                                       2027
# eventName                            5000 Meter Run
# eventDistance                                  5000
# ageGroupName                                   None
# meetName            Cathlolic Memorial Invitational
# videoId                                           0
# divisionId                                       72
# divisionName                                   None
# roundName                                    Finals
# genderName                                     Boys
# eventGenreOrder                                   2
# performanceVideoId                             None
# mark                                       23:00.90
# Race Key                        Catholic Mem Invite
# Location                              Franklin Park
# Full Name                               Javien Leon
# Race Name                       Catholic Mem Invite
# Time                         0 days 00:23:00.900000
# Time_str                                00:23:00.90
# Team Place                                       10

# %%
df_results.head(2).T
# Out:
#                                                   142  \
# id                                          152238976
# eventCode                                       5000m
# gender                                              M
# athleteId                                    13978101
# meetId                                         577861
# teamId                                          19337
# round                                               f
# heat                                                1
# place                                               1
# windReading
# units                                          947800
# teamName                     Newton North High School
# firstName                                     Gabriel
# lastName                                        Grove
# gradYear                                         2024
# eventName                              5000 Meter Run
# eventDistance                                    5000
# ageGroupName                                     None
# meetName            Bay State Conference Championship
# videoId                                             0
# divisionId                                         99
# divisionName                                     None
# roundName                                      Finals
# genderName                                       Boys
# eventGenreOrder                                     2
# performanceVideoId                               None
# mark                                         15:47.80
# Race Key                                    Bay State
# Location                                     Wrentham
# Full Name                               Gabriel Grove
# Race Name                                   Bay State
# Time                           0 days 00:15:47.800000
# Time_str                                  00:15:47.80
# Team Place                                          1
#
#                                                   143
# id                                          152238977
# eventCode                                       5000m
# gender                                              M
# athleteId                                    12408079
# meetId                                         577861
# teamId                                          19417
# round                                               f
# heat                                                1
# place                                               2
# windReading
# units                                          958000
# teamName                        Wellesley High School
# firstName                                     Stephen
# lastName                                   Goehringer
# gradYear                                         2024
# eventName                              5000 Meter Run
# eventDistance                                    5000
# ageGroupName                                     None
# meetName            Bay State Conference Championship
# videoId                                             0
# divisionId                                         99
# divisionName                                     None
# roundName                                      Finals
# genderName                                       Boys
# eventGenreOrder                                     2
# performanceVideoId                               None
# mark                                         15:58.00
# Race Key                                    Bay State
# Location                                     Wrentham
# Full Name                          Stephen Goehringer
# Race Name                                   Bay State
# Time                                  0 days 00:15:58
# Time_str                                     00:15:58
# Team Place                                          1

# %%
df_results[df_results['lastName']=='Crounse'].T
# Out:
#                                                       21
# id                                             152160294
# eventCode                                          5000m
# gender                                                 M
# athleteId                                       12575365
# meetId                                            572592
# teamId                                             19231
# round                                                  f
# heat                                                   1
# place                                                 29
# windReading
# units                                            1083100
# teamName                    Concord Carlisle High School
# firstName                                           Luke
# lastName                                         Crounse
# gradYear                                            2026
# eventName                                 5000 Meter Run
# eventDistance                                       5000
# ageGroupName                                        None
# meetName            Dual County League Championship Meet
# videoId                                                0
# divisionId                                            99
# divisionName                                        None
# roundName                                         Finals
# genderName                                          Boys
# eventGenreOrder                                        2
# performanceVideoId                                  None
# mark                                            18:03.10
# Race Key                            Dual County Thorpe 2
# Location                                   Franklin Park
# Full Name                                   Luke Crounse
# Race Name                                    Dual County
# Time                              0 days 00:18:03.100000
# Time_str                                     00:18:03.10
# Team Place                                             4

# %%
df_results.dtypes
# Out:
# id                             object
# eventCode                      object
# gender                         object
# athleteId                      object
# meetId                         object
# teamId                         object
# round                          object
# heat                           object
# place                          object
# windReading                    object
# units                          object
# teamName                       object
# firstName                      object
# lastName                       object
# gradYear                       object
# eventName                      object
# eventDistance                  object
# ageGroupName                   object
# meetName                       object
# videoId                         int64
# divisionId                     object
# divisionName                   object
# roundName                      object
# genderName                     object
# eventGenreOrder                 int64
# performanceVideoId             object
# mark                           object
# Race Key                       object
# Location                       object
# Full Name                      object
# Race Name                      object
# Time                  timedelta64[ns]
# Time_str                       object
# Team Place                      int64
# dtype: object

# %% [markdown]
# # Reference

# %%
# FOR REFERENCE


# # The URL of the API endpoint
# url = 'https://ma.milesplit.com/api/v1/meets/578420/performances'

# url = 'https://ma.milesplit.com/api/v1/meets/578420/performances?resultsId=986788&fields=id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo&teamScores=true'


# # Any query parameters or headers you need to send with the request
# params = {'resultsID': '986788',
#           'fields': 'id%2CmeetId%2CmeetName%2CteamId%2CvideoId%2CteamName%2CathleteId%2CfirstName%2ClastName%2Cgender%2CgenderName%2CdivisionId%2CdivisionName%2CageGroupName%2CgradYear%2CeventName%2CeventCode%2CeventDistance%2CeventGenreOrder%2Cround%2CroundName%2Cheat%2Cunits%2Cmark%2Cplace%2CwindReading%2CprofileUrl%2CteamProfileUrl%2C+performanceVideoId%2C+teamLogo',
#           'teamScores': 'true'}

# #headers = {'Authorization': 'Bearer YOUR_ACCESS_TOKEN'}

# # Make the GET request
# response = requests.get(url) # , params=params) # , headers=headers)

# # Check if the request was successful
# if response.status_code == 200:
#     # Parse the response JSON if the content type is correct
#     if 'application/json' in response.headers.get('Content-Type'):
#         data = response.json()
#         print(data)
#     else:
#         print('Response content is not in JSON format.')
# else:
#     print(f'Error: {response.status_code}')
#     print(response.text)
